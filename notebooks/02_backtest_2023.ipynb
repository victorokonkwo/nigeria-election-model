# %% [markdown]
# # 02 — Backtest: 2023 Election
#
# Train on ≤2019, predict 2023. Evaluate calibration and scoring metrics.

# %%
import pandas as pd
from ngforecast.calibration.backtest import run_backtest
from ngforecast.calibration.scores import score_summary
