# %% [markdown]
# # 03 — Scenario Review
#
# Explore game-theory scenarios: coalitions, entry/exit, QRE migration.
# Visualize how each scenario shifts win probabilities.

# %%
import yaml
import pandas as pd

with open('../config/scenarios.yaml') as f:
    scenarios = yaml.safe_load(f)

for name, s in scenarios.items():
    print(f"{name}: π = {s['prior_probability']:.2f} — {s['label']}")
