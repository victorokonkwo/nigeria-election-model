# %% [markdown]
# # 01 — Exploratory Data Analysis: State × Election Panel
#
# Explores the processed panel data: distributions, correlations, spatial patterns.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

panel = pd.read_parquet('../data/processed/panel.parquet')
panel.head()
